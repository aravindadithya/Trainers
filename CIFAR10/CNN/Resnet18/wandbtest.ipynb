# %%
import CIFAR10.CNN.Resnet18.config as tr
import utils.trainer as t
import torch
print(torch.__version__)
# Out:
# Current Path: /workspaces/Trainers
# 2.10.0+cu130

# %%
config = tr.get_config(run_id="10")

# %%
net = t.get_trained_net(config)
print(f"test_acc: {t.get_acc_ce(net.cuda(), config['val_loader'])}")
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: Enter your choice:
# wandb: You chose 'Create a W&B account'
# wandb: Create an account here: https://wandb.ai/authorize?signup=true&ref=models
# wandb: After creating your account, create a new API key and store it securely.
# wandb: Paste your API key and hit enter:wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb:   1 of 1 files downloaded.
# Loaded weights from artifact: model-1:latest
# test_acc: 89.69

# %%
t.train_network(config=config, num_epochs=20, checkpoint_interval=10)
# Out:
# Initializing Wandb:
# Tracking run with wandb version 0.24.2
# Run data is saved locally in <code>/workspaces/Trainers/CIFAR10/CNN/Resnet18/wandb/run-20260228_153737-10</code>
# Resuming run <strong><a href='https://wandb.ai/Trainers100/CIFAR10/runs/10' target="_blank">Resnet18_CNN</a></strong> to <a href='https://wandb.ai/Trainers100/CIFAR10' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/Trainers100/CIFAR10' target="_blank">https://wandb.ai/Trainers100/CIFAR10</a>
#  View run at <a href='https://wandb.ai/Trainers100/CIFAR10/runs/10' target="_blank">https://wandb.ai/Trainers100/CIFAR10/runs/10</a>
# Collected 10 images for visualization (1 from each of 10 classes).
# Resuming from previous run...
# Best Val Acc so far in the training run: 86.97
# EPOCH:  11
# Time:  21.168822288513184
# Generating Visuals...
# Generating Layer Visuals (GradCAM, IG, FeatureMaps)...
# ...

# %%
print(net)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
